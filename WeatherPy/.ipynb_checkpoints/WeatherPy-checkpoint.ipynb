# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 601

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=" + weather_api_key

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | vila franca do campo
# Processing Record 2 of Set 1 | murun-kuren
# Processing Record 3 of Set 1 | anadyr
# Processing Record 4 of Set 1 | eskilstuna
# Processing Record 5 of Set 1 | tiksi
# Processing Record 6 of Set 1 | dudinka
# Processing Record 7 of Set 1 | seferihisar
# Processing Record 8 of Set 1 | invercargill
# Processing Record 9 of Set 1 | saipan
# Processing Record 10 of Set 1 | papatowai
# Processing Record 11 of Set 1 | port mathurin
# Processing Record 12 of Set 1 | adamstown
# Processing Record 13 of Set 1 | waitangi
# Processing Record 14 of Set 1 | flying fish cove
# Processing Record 15 of Set 1 | kalevala
# Processing Record 16 of Set 1 | punta arenas
# Processing Record 17 of Set 1 | acapulco de juarez
# Processing Record 18 of Set 1 | puerto natales
# Processing Record 19 of Set 1 | new norfolk
# Processing Record 20 of Set 1 | college
# ...

# %%
city_data
# Out:
# [{'City': 'vila franca do campo',
#   'Lat': 37.7167,
#   'Lng': -25.4333,
#   'Max Temp': 22.23,
#   'Humidity': 99,
#   'Cloudiness': 92,
#   'Wind Speed': 13.63,
#   'Country': 'PT',
#   'Date': 1697425782},
#  {'City': 'murun-kuren',
#   'Lat': 49.6342,
#   'Lng': 100.1625,
#   'Max Temp': 4.94,
#   'Humidity': 47,
#   'Cloudiness': 55,
#   'Wind Speed': 9.49,
#   'Country': 'MN',
#   'Date': 1697425782},
#  {'City': 'anadyr',
#   'Lat': 64.75,
#   'Lng': 177.4833,
#   'Max Temp': 2.28,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 1,
#   'Country': 'RU',
#   'Date': 1697425782},
#  {'City': 'eskilstuna',
#   'Lat': 59.3666,
#   'Lng': 16.5077,
#   'Max Temp': 0.88,
#   'Humidity': 67,
#   'Cloudiness': 3,
#   'Wind Speed': 3.06,
#   'Country': 'SE',
#   'Date': 1697425782},
#  {'City': 'tiksi',
#   'Lat': 71.6872,
#   'Lng': 128.8694,
#   'Max Temp': -7.78,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 7.62,
#   'Country': 'RU',
# ...

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
# Show Record Count
city_data_df.count()
# Out:
# City          573
# Lat           573
# Lng           573
# Max Temp      573
# Humidity      573
# Cloudiness    573
# Wind Speed    573
# Country       573
# Date          573
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  vila franca do campo  37.7167  -25.4333     22.23        99          92
# 1           murun-kuren  49.6342  100.1625      4.94        47          55
# 2                anadyr  64.7500  177.4833      2.28        87         100
# 3            eskilstuna  59.3666   16.5077      0.88        67           3
# 4                 tiksi  71.6872  128.8694     -7.78        89         100
#
#    Wind Speed Country        Date
# 0       13.63      PT  1697425782
# 1        9.49      MN  1697425782
# 2        1.00      RU  1697425782
# 3        3.06      SE  1697425782
# 4        7.62      RU  1697425783

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                          City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0        vila franca do campo  37.7167  -25.4333     22.23        99
# 1                 murun-kuren  49.6342  100.1625      4.94        47
# 2                      anadyr  64.7500  177.4833      2.28        87
# 3                  eskilstuna  59.3666   16.5077      0.88        67
# 4                       tiksi  71.6872  128.8694     -7.78        89
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                92       13.63      PT  1697425782
# 1                55        9.49      MN  1697425782
# 2               100        1.00      RU  1697425782
# 3                 3        3.06      SE  1697425782
# 4               100        7.62      RU  1697425783

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], alpha = .9, edgecolors = "k")
# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.title(f"City Latitude vs. Temperature (C) (2022-10-18)")
plt.grid(True)
plt.tight_layout()
# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], alpha = .9, edgecolors = "k")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title(f"City Latitude vs. Humidity (2022-10-18)")
plt.grid(True)
plt.tight_layout()

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], alpha = .9, edgecolors = "k")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title(f"City Latitude vs. Cloudiness (2022-10-18)")
plt.grid(True)
plt.tight_layout()

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], alpha = .9, edgecolors = "k")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.title(f"City Latitude vs. Wind Speed (2022-10-18)")
plt.grid(True)
plt.tight_layout()

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def line_reg_plot(x_values, y_values, title, text_coordinates):
    # line equation strings
    (slope, intercept, rvalue, pvalue, stderr) = linregress (x_values,y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + " x + " + str(round(intercept,2))
    
    #general variable/plot information:
    plt.scatter(x_values,y_values)
    plt.plot(x_values, regress_values, "r-")
    plt.annotate(line_eq,text_coordinates, fontsize=15, color="red")
    plt.xlabel("Latitude")
    plt.ylabel(title)
    print(f"The r-squared is: {rvalue}")
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]

# Display sample data
northern_hemi_df.head()
# Out:
#                          City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0        vila franca do campo  37.7167  -25.4333     22.23        99
# 1                 murun-kuren  49.6342  100.1625      4.94        47
# 2                      anadyr  64.7500  177.4833      2.28        87
# 3                  eskilstuna  59.3666   16.5077      0.88        67
# 4                       tiksi  71.6872  128.8694     -7.78        89
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                92       13.63      PT  1697425782
# 1                55        9.49      MN  1697425782
# 2               100        1.00      RU  1697425782
# 3                 3        3.06      SE  1697425782
# 4               100        7.62      RU  1697425783

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] <0)]

# Display sample data
southern_hemi_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 7         invercargill -46.4000  168.3500      9.45        90          96
# 9            papatowai -46.5619  169.4708     10.52        81          97
# 10       port mathurin -19.6833   63.4167     23.86        82           2
# 11           adamstown -25.0660 -130.1015     21.83        81          64
# 12            waitangi -43.9535 -176.5597     13.79        71          39
#
#          Wind Speed Country        Date
# City_ID
# 7              3.13      NZ  1697425783
# 9              4.23      NZ  1697425783
# 10             5.41      MU  1697425784
# 11             2.21      PN  1697425784
# 12             2.68      NZ  1697425784

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
line_reg_plot(x_values, y_values, "Max Temp", (6,-10))
# Out:
# The r-squared is: -0.8858634232603433

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
line_reg_plot(x_values, y_values, "Max Temp", (6,-10))
# Out:
# The r-squared is: 0.7228372399143875

# %% [markdown]
# Discussion about the linear relationship: The Northern Hemisphere decreases in temperature as the latitude increases.  The Southern Hemisphere increase as the latitude increases.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
line_reg_plot(x_values, y_values, "Humidity", (6,-10))
# Out:
# The r-squared is: 0.17756887385369974

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
line_reg_plot(x_values, y_values, "Humidity", (6,-10))
# Out:
# The r-squared is: 0.07196970090334782

# %%
Discussion about the linear relationship:
    -The humidity in the Northern Hemisphere seems to have both high and low humidity percentages between the 20 and 55 latitude areas.
    -The humidity in the Southern Hemisphere has the both high and low humidity percentages between the -10 and -30 latitude.
# Out:
#   Cell In[61], line 1
#     Discussion about the linear relationship:
#                ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
line_reg_plot(x_values, y_values, "Cloudiness", (6,-10))

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
line_reg_plot(x_values, y_values, "Cloudiness", (6,-10))

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
line_reg_plot(x_values, y_values, "Wind Speed", (6,-10))

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
line_reg_plot(x_values, y_values, "Wind Speed", (6,-10))

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
